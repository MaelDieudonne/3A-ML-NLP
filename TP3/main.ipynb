# %% [markdown]
# # NLP Lab: Language Models
#
# In this lab, we will build the main components of the GPT-2 model and train a small model on poems by Victor Hugo.
#
# The questions are included in this notebook. To run the training, you will need to modify the `gpt_single_head.py` file, which is also available in the Git repository.
#
# ## Data
#
# The training data consists of a collection of poems by Victor Hugo, sourced from [gutenberg.org](https://www.gutenberg.org/). The dataset is available in the `data` directory.
#
# To reduce model complexity, we will model the text at the character level. Typically, language models process sequences of subwords using [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) such as BPE, SentencePiece, or WordPiece.
#
# #### Questions:
# - Using [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), display the number of unique characters in the text and the frequency of each character.

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE
counter = collections.Counter(text)
chars = counter.keys()
###

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encoding / Decoding
#
# To transform the text into a vector for the neural network, each character must be encoded as an integer.
#
# The following functions perform the encoding and decoding of characters:

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string

# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) == testString

# %% [markdown]
# ### Train/Validation Split
#
# Since the goal is to predict poems, the lines should not be shuffled randomly. Instead, we must preserve the order of the lines in the text and take only the first 90% for training, while using the remaining 10% to monitor learning.
#
# #### Questions:
# - Split the data into `train_data` (90%) and `val_data` (10%) using slicing on the dataset.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
split_idx = int(0.9 * len(data))
train_data = data[:split_idx]
val_data = data[split_idx:]
print(f'Train size: {len(train_data)}, Test size: {len(val_data)}')
###
# Out:
# Train size: 256699, Test size: 28523

# %% [markdown]
# ### Context
#
# The language model has a parameter that defines the maximum context size to consider when predicting the next character. This context is called `block_size`. The training data consists of sequences of consecutive characters, randomly sampled from the training set, with a length of `block_size`.
#
# If the starting character of the sequence is `i`, then the context sequence is:
# ```python
# x = data[i:i+block_size]
# ```
# And the target value to predict at each position in the context is the next character:
# ```python
# y = data[i+1:i+block_size+1]
# ```

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([189806])
# context is >a< target is >s<
# context is >as< target is > <
# context is >as < target is >l<
# context is >as l< target is >e<
# context is >as le< target is >s<
# context is >as les< target is > <
# context is >as les < target is >f<
# context is >as les f< target is >o<

# %% [markdown]
# ### Defining Batches
#
# The training batches consist of multiple character sequences randomly sampled from `train_data`. To randomly select a sequence for the batch, we need to randomly pick a starting point in `train_data` and extract the following `block_size` characters. When selecting the starting point, ensure that there are enough characters remaining after it to form a full sequence of `block_size` characters.
#
# #### Questions:
# - Create the batches `x` by selecting `batch_size` sequences of length `block_size` starting from a randomly chosen index `i`. Stack the examples using `torch.stack`.
# - Create the batches `y` by adding the next character following each sequence in `x`. Stack the examples using `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ## YOUR CODE HERE
    # select batch_size starting points in the data, store them in a list called starting_points
    starting_points = torch.randint(0, len(data) - block_size, (batch_size,))

    # x is the sequence of integer starting at each straing point and of length block_size
    x = torch.stack([data[i : i + block_size] for i in starting_points])
    
    # y is the character after each starting position
    y = torch.stack([data[i + 1 : i + block_size + 1] for i in starting_points])

    ### 
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### First Model: A Bigram Model
#
# The first model we will implement is a bigram model. It predicts the next character based only on the current character. This model can be stored in a simple matrix: for each character (row), we store the probability distribution over all possible next characters (columns). This can be implemented using a simple [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html) layer in PyTorch.
#
# #### Questions:
# - In the constructor, define an Embedding layer of size `vocab_size × vocab_size`.
# - In the `forward` method, apply the embedding layer to the batch of indices (`x`).
# - In the `forward` method, define the loss as `cross_entropy` between the predictions and the target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
if torch.cuda.is_available(): device = torch.device("cuda")
elif torch.backends.mps.is_available(): device = torch.device("mps")
else: device = torch.device("cpu")

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.token_embedding = nn.Embedding(vocab_size, vocab_size)  
        ## 
        
    def forward(self, idx, targets=None):
        # idx and targets are both (Batch,Time) tensor of integers
        # YOUR CODE HERE
        logits = self.token_embedding(idx)
        ## 
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch * Time, Channels)
            targets = targets.view(Batch * Time)
            
            # negative log likelihood between prediction and target
            # YOUR CODE HERE
            loss = nn.functional.cross_entropy(logits, targets)
            ## 

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

vocab_size = len(chars)
model = BigramLanguageModel(vocab_size)

# send the model to device
m = model.to(device)

# %% [markdown]
# ### Model Before Training
#
# At this stage, the model has not yet been trained—it has only been initialized. However, we can already compute the loss on a random batch. Since the weights are initialized with a normal distribution \( N(0,1) \) for each dimension, the expected loss after initialization should be close to `-ln(1/vocab_size)`, as the entropy is maximal.

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'Expected loss {-math.log(1.0/vocab_size)}')
print (f'Computed loss {loss}')
# Out:
# torch.Size([32, 101])
# Expected loss 4.61512051684126
# Computed loss 5.095336437225342

# %% [markdown]
# ### Using the Model for Prediction
#
# To use the model for prediction, we need to provide an initial character to start the sequence—this is called the prompt. In our case, we can initialize the generation with the newline character (`\n`) to start a new sentence.
#
# #### Questions:
# - Create a prompt as a tensor of size `(1,1)` containing the integer corresponding to the character `\n`.
# - Generate a sequence of 100 characters from this prompt using the functions `m.generate` and `decode`.
# - How does the generated sentence look?

# %%
print (encode(['\n']))
## YOUR CODE HERE
prompt = torch.tensor([[3]], dtype=torch.long).to(device)
gen_sequence = m.generate(prompt, max_new_tokens=100)
generated_text = decode(gen_sequence.tolist()[0])

print(generated_text)
###
# Out:
# [3]
#
# yaK[wà[OaéYB6âù4qÆH m1'iXGb·?fJî'2g[HÎxIOSD:3d4mDxîZ!!ûuhlÀ9xIsfâ-Y8]w1«û.N«cî'5Dv»îQ5lDH[YbLyEÎôfZR

# %% [markdown]
# **Comment**: The generated sequence looks like a random sequence of characters. It is totally different from natural langague.

# %% [markdown]
# ### Training
#
# For training, we use the [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) optimizer with a learning rate of `1e-3`. Each training iteration consists of the following steps:
#
# - Generate a batch
# - Apply the neural network (forward pass) and compute the loss: `model(xb, yb)`
# - Compute the gradient (after resetting accumulated gradients): `loss.backward()`
# - Update the parameters: `optimizer.step()`

# %%
max_iters = 10000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 200

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.0695, val loss 4.8891
# step 10: train loss 5.0190, val loss 4.8945
# step 20: train loss 5.0148, val loss 4.8692
# step 30: train loss 5.0082, val loss 4.8917
# step 40: train loss 4.9846, val loss 4.8752
# step 50: train loss 4.9986, val loss 4.8904
# step 60: train loss 4.9863, val loss 4.8653
# step 70: train loss 4.9960, val loss 4.8341
# step 80: train loss 4.9714, val loss 4.8630
# step 90: train loss 4.9391, val loss 4.8365
# step 100: train loss 4.9721, val loss 4.7997
# step 110: train loss 4.9375, val loss 4.8188
# step 120: train loss 4.9502, val loss 4.8088
# step 130: train loss 4.8998, val loss 4.7886
# step 140: train loss 4.9205, val loss 4.7885
# step 150: train loss 4.8987, val loss 4.7906
# step 160: train loss 4.9030, val loss 4.7790
# step 170: train loss 4.8872, val loss 4.7574
# step 180: train loss 4.8602, val loss 4.7750
# step 190: train loss 4.8704, val loss 4.7268
# step 200: train loss 4.8604, val loss 4.7512
# step 210: train loss 4.8477, val loss 4.7513
# step 220: train loss 4.8358, val loss 4.7344
# step 230: train loss 4.8374, val loss 4.6869
# step 240: train loss 4.8447, val loss 4.6969
# step 250: train loss 4.8434, val loss 4.6661
# step 260: train loss 4.8023, val loss 4.6759
# step 270: train loss 4.8017, val loss 4.6856
# step 280: train loss 4.7998, val loss 4.6833
# step 290: train loss 4.7806, val loss 4.6724
# step 300: train loss 4.7665, val loss 4.6683
# step 310: train loss 4.7462, val loss 4.6513
# step 320: train loss 4.7656, val loss 4.6190
# step 330: train loss 4.7329, val loss 4.6247
# step 340: train loss 4.7504, val loss 4.6256
# step 350: train loss 4.7467, val loss 4.6776
# step 360: train loss 4.7267, val loss 4.5894
# step 370: train loss 4.7067, val loss 4.6085
# step 380: train loss 4.7138, val loss 4.6058
# step 390: train loss 4.7002, val loss 4.5788
# step 400: train loss 4.6918, val loss 4.5875
# step 410: train loss 4.6871, val loss 4.5933
# step 420: train loss 4.6740, val loss 4.6041
# step 430: train loss 4.6785, val loss 4.5530
# step 440: train loss 4.6646, val loss 4.5540
# step 450: train loss 4.6571, val loss 4.5784
# step 460: train loss 4.6555, val loss 4.5394
# step 470: train loss 4.6439, val loss 4.5368
# step 480: train loss 4.6205, val loss 4.5186
# step 490: train loss 4.6272, val loss 4.5630
# step 500: train loss 4.6143, val loss 4.5015
# step 510: train loss 4.5998, val loss 4.4985
# step 520: train loss 4.5863, val loss 4.4934
# step 530: train loss 4.5687, val loss 4.4774
# step 540: train loss 4.5727, val loss 4.4848
# step 550: train loss 4.5545, val loss 4.4621
# step 560: train loss 4.5746, val loss 4.4491
# step 570: train loss 4.5612, val loss 4.4871
# step 580: train loss 4.5491, val loss 4.4698
# step 590: train loss 4.5512, val loss 4.4692
# step 600: train loss 4.5346, val loss 4.4507
# step 610: train loss 4.5293, val loss 4.4279
# step 620: train loss 4.5302, val loss 4.4575
# step 630: train loss 4.5095, val loss 4.4332
# step 640: train loss 4.5094, val loss 4.4002
# step 650: train loss 4.5072, val loss 4.3934
# step 660: train loss 4.4852, val loss 4.3987
# step 670: train loss 4.4937, val loss 4.3928
# step 680: train loss 4.4847, val loss 4.3623
# step 690: train loss 4.4384, val loss 4.3751
# step 700: train loss 4.4744, val loss 4.3550
# step 710: train loss 4.4809, val loss 4.3676
# step 720: train loss 4.4476, val loss 4.3531
# step 730: train loss 4.4595, val loss 4.3682
# step 740: train loss 4.4218, val loss 4.3384
# step 750: train loss 4.4223, val loss 4.3339
# step 760: train loss 4.4255, val loss 4.3190
# step 770: train loss 4.3971, val loss 4.3219
# step 780: train loss 4.4076, val loss 4.3141
# step 790: train loss 4.3677, val loss 4.3246
# step 800: train loss 4.3764, val loss 4.3009
# step 810: train loss 4.3787, val loss 4.2869
# step 820: train loss 4.3737, val loss 4.2923
# step 830: train loss 4.3681, val loss 4.3060
# step 840: train loss 4.3890, val loss 4.2655
# step 850: train loss 4.3534, val loss 4.2452
# step 860: train loss 4.3404, val loss 4.2745
# step 870: train loss 4.3608, val loss 4.2628
# step 880: train loss 4.3570, val loss 4.2334
# step 890: train loss 4.3069, val loss 4.2457
# step 900: train loss 4.3381, val loss 4.2319
# step 910: train loss 4.3009, val loss 4.2198
# step 920: train loss 4.2948, val loss 4.2567
# step 930: train loss 4.2824, val loss 4.2086
# step 940: train loss 4.2886, val loss 4.2042
# step 950: train loss 4.2757, val loss 4.2074
# step 960: train loss 4.2758, val loss 4.1933
# step 970: train loss 4.2732, val loss 4.1831
# step 980: train loss 4.2629, val loss 4.1539
# step 990: train loss 4.2339, val loss 4.2044
# step 1000: train loss 4.2548, val loss 4.1904
# step 1010: train loss 4.2413, val loss 4.1678
# step 1020: train loss 4.2416, val loss 4.1621
# step 1030: train loss 4.2218, val loss 4.1566
# step 1040: train loss 4.2434, val loss 4.1523
# step 1050: train loss 4.2197, val loss 4.1324
# step 1060: train loss 4.2059, val loss 4.1421
# step 1070: train loss 4.1850, val loss 4.1329
# step 1080: train loss 4.1878, val loss 4.1296
# step 1090: train loss 4.1786, val loss 4.1009
# step 1100: train loss 4.1600, val loss 4.0960
# step 1110: train loss 4.1750, val loss 4.1053
# step 1120: train loss 4.1784, val loss 4.1116
# step 1130: train loss 4.1634, val loss 4.0831
# step 1140: train loss 4.1480, val loss 4.1142
# step 1150: train loss 4.1670, val loss 4.0779
# step 1160: train loss 4.1372, val loss 4.0637
# step 1170: train loss 4.1596, val loss 4.0519
# step 1180: train loss 4.1575, val loss 4.0868
# step 1190: train loss 4.1212, val loss 4.0502
# step 1200: train loss 4.1449, val loss 4.0293
# step 1210: train loss 4.1147, val loss 4.0680
# step 1220: train loss 4.1054, val loss 4.0546
# step 1230: train loss 4.0848, val loss 4.0396
# step 1240: train loss 4.1021, val loss 4.0266
# step 1250: train loss 4.0910, val loss 4.0274
# step 1260: train loss 4.0658, val loss 4.0257
# step 1270: train loss 4.0874, val loss 3.9775
# step 1280: train loss 4.0896, val loss 3.9934
# step 1290: train loss 4.0717, val loss 4.0115
# step 1300: train loss 4.0652, val loss 3.9992
# step 1310: train loss 4.0435, val loss 3.9308
# step 1320: train loss 4.0583, val loss 3.9797
# step 1330: train loss 4.0562, val loss 3.9701
# step 1340: train loss 4.0478, val loss 3.9621
# step 1350: train loss 4.0045, val loss 3.9493
# step 1360: train loss 4.0143, val loss 3.9656
# step 1370: train loss 3.9946, val loss 3.9674
# step 1380: train loss 3.9854, val loss 3.9361
# step 1390: train loss 4.0096, val loss 3.9501
# step 1400: train loss 3.9939, val loss 3.9376
# step 1410: train loss 3.9772, val loss 3.9236
# step 1420: train loss 3.9863, val loss 3.9228
# step 1430: train loss 3.9988, val loss 3.9264
# step 1440: train loss 3.9820, val loss 3.9034
# step 1450: train loss 3.9651, val loss 3.8794
# step 1460: train loss 3.9614, val loss 3.8838
# step 1470: train loss 3.9617, val loss 3.8907
# step 1480: train loss 3.9443, val loss 3.8691
# step 1490: train loss 3.9461, val loss 3.8458
# step 1500: train loss 3.9514, val loss 3.8889
# step 1510: train loss 3.9096, val loss 3.8542
# step 1520: train loss 3.9003, val loss 3.8695
# step 1530: train loss 3.9067, val loss 3.8685
# step 1540: train loss 3.9179, val loss 3.8601
# step 1550: train loss 3.9073, val loss 3.8668
# step 1560: train loss 3.8844, val loss 3.8435
# step 1570: train loss 3.9045, val loss 3.8526
# step 1580: train loss 3.8848, val loss 3.8483
# step 1590: train loss 3.8800, val loss 3.8079
# step 1600: train loss 3.8795, val loss 3.8041
# step 1610: train loss 3.8779, val loss 3.8164
# step 1620: train loss 3.8813, val loss 3.8040
# step 1630: train loss 3.8595, val loss 3.8335
# step 1640: train loss 3.8650, val loss 3.8103
# step 1650: train loss 3.8681, val loss 3.7921
# step 1660: train loss 3.8599, val loss 3.8089
# step 1670: train loss 3.8465, val loss 3.7707
# step 1680: train loss 3.8164, val loss 3.7945
# step 1690: train loss 3.8390, val loss 3.7501
# step 1700: train loss 3.8219, val loss 3.7434
# step 1710: train loss 3.8363, val loss 3.8003
# step 1720: train loss 3.8313, val loss 3.7611
# step 1730: train loss 3.7932, val loss 3.7420
# step 1740: train loss 3.8177, val loss 3.7526
# step 1750: train loss 3.8107, val loss 3.7587
# step 1760: train loss 3.8269, val loss 3.7613
# step 1770: train loss 3.7812, val loss 3.7467
# step 1780: train loss 3.7975, val loss 3.7459
# step 1790: train loss 3.7816, val loss 3.7648
# step 1800: train loss 3.7898, val loss 3.7467
# step 1810: train loss 3.7631, val loss 3.7100
# step 1820: train loss 3.7881, val loss 3.7030
# step 1830: train loss 3.7713, val loss 3.7012
# step 1840: train loss 3.7562, val loss 3.7153
# step 1850: train loss 3.7475, val loss 3.6976
# step 1860: train loss 3.7404, val loss 3.7043
# step 1870: train loss 3.7168, val loss 3.7045
# step 1880: train loss 3.7470, val loss 3.6657
# step 1890: train loss 3.7351, val loss 3.6831
# step 1900: train loss 3.7442, val loss 3.6549
# step 1910: train loss 3.7071, val loss 3.6817
# step 1920: train loss 3.7341, val loss 3.6677
# step 1930: train loss 3.6942, val loss 3.6780
# step 1940: train loss 3.7016, val loss 3.6931
# step 1950: train loss 3.6896, val loss 3.6743
# step 1960: train loss 3.6856, val loss 3.6504
# step 1970: train loss 3.6952, val loss 3.6762
# step 1980: train loss 3.6939, val loss 3.6489
# step 1990: train loss 3.6772, val loss 3.6335
# step 2000: train loss 3.6891, val loss 3.6694
# step 2010: train loss 3.6785, val loss 3.6154
# step 2020: train loss 3.6606, val loss 3.6369
# step 2030: train loss 3.6816, val loss 3.6294
# step 2040: train loss 3.6495, val loss 3.6428
# step 2050: train loss 3.6693, val loss 3.6334
# step 2060: train loss 3.6525, val loss 3.6147
# step 2070: train loss 3.6467, val loss 3.6389
# step 2080: train loss 3.6289, val loss 3.5916
# step 2090: train loss 3.6239, val loss 3.5756
# step 2100: train loss 3.6335, val loss 3.5794
# step 2110: train loss 3.6083, val loss 3.5859
# step 2120: train loss 3.6150, val loss 3.5848
# step 2130: train loss 3.6051, val loss 3.5613
# step 2140: train loss 3.6153, val loss 3.5539
# step 2150: train loss 3.6041, val loss 3.5725
# step 2160: train loss 3.6209, val loss 3.5786
# step 2170: train loss 3.5775, val loss 3.5577
# step 2180: train loss 3.5931, val loss 3.5368
# step 2190: train loss 3.5770, val loss 3.5481
# step 2200: train loss 3.5821, val loss 3.5857
# step 2210: train loss 3.5629, val loss 3.5614
# step 2220: train loss 3.5742, val loss 3.5726
# step 2230: train loss 3.5669, val loss 3.5496
# step 2240: train loss 3.5714, val loss 3.5230
# step 2250: train loss 3.5728, val loss 3.5223
# step 2260: train loss 3.5520, val loss 3.5362
# step 2270: train loss 3.5636, val loss 3.5130
# step 2280: train loss 3.5556, val loss 3.5160
# step 2290: train loss 3.5540, val loss 3.5242
# step 2300: train loss 3.5440, val loss 3.5092
# step 2310: train loss 3.5226, val loss 3.4911
# step 2320: train loss 3.5474, val loss 3.4913
# step 2330: train loss 3.5350, val loss 3.5358
# step 2340: train loss 3.5256, val loss 3.4854
# step 2350: train loss 3.5497, val loss 3.5042
# step 2360: train loss 3.5271, val loss 3.4791
# step 2370: train loss 3.5241, val loss 3.4799
# step 2380: train loss 3.5009, val loss 3.5177
# step 2390: train loss 3.4741, val loss 3.4939
# step 2400: train loss 3.4617, val loss 3.4729
# step 2410: train loss 3.5008, val loss 3.4762
# step 2420: train loss 3.4976, val loss 3.4724
# step 2430: train loss 3.4641, val loss 3.4624
# step 2440: train loss 3.4903, val loss 3.4666
# step 2450: train loss 3.4743, val loss 3.4658
# step 2460: train loss 3.4828, val loss 3.4408
# step 2470: train loss 3.4409, val loss 3.4704
# step 2480: train loss 3.4712, val loss 3.4820
# step 2490: train loss 3.4607, val loss 3.4657
# step 2500: train loss 3.4468, val loss 3.4164
# step 2510: train loss 3.4640, val loss 3.4228
# step 2520: train loss 3.4357, val loss 3.4078
# step 2530: train loss 3.4595, val loss 3.4152
# step 2540: train loss 3.4525, val loss 3.4028
# step 2550: train loss 3.4318, val loss 3.4132
# step 2560: train loss 3.4299, val loss 3.3954
# step 2570: train loss 3.4230, val loss 3.3977
# step 2580: train loss 3.4250, val loss 3.3894
# step 2590: train loss 3.4428, val loss 3.4358
# step 2600: train loss 3.4200, val loss 3.3856
# step 2610: train loss 3.4031, val loss 3.3868
# step 2620: train loss 3.4351, val loss 3.3857
# step 2630: train loss 3.3978, val loss 3.3750
# step 2640: train loss 3.3881, val loss 3.3982
# step 2650: train loss 3.4046, val loss 3.3459
# step 2660: train loss 3.4011, val loss 3.3790
# step 2670: train loss 3.3634, val loss 3.3852
# step 2680: train loss 3.4054, val loss 3.4086
# step 2690: train loss 3.3585, val loss 3.3677
# step 2700: train loss 3.3984, val loss 3.3492
# step 2710: train loss 3.3605, val loss 3.3579
# step 2720: train loss 3.3800, val loss 3.3621
# step 2730: train loss 3.3791, val loss 3.3624
# step 2740: train loss 3.3858, val loss 3.3558
# step 2750: train loss 3.3599, val loss 3.3499
# step 2760: train loss 3.3789, val loss 3.3584
# step 2770: train loss 3.3533, val loss 3.3521
# step 2780: train loss 3.3624, val loss 3.3352
# step 2790: train loss 3.3403, val loss 3.3583
# step 2800: train loss 3.3578, val loss 3.3335
# step 2810: train loss 3.3447, val loss 3.3109
# step 2820: train loss 3.3397, val loss 3.3310
# step 2830: train loss 3.3489, val loss 3.3175
# step 2840: train loss 3.3320, val loss 3.3436
# step 2850: train loss 3.3535, val loss 3.3026
# step 2860: train loss 3.3037, val loss 3.3111
# step 2870: train loss 3.3207, val loss 3.2891
# step 2880: train loss 3.2781, val loss 3.3411
# step 2890: train loss 3.3260, val loss 3.3045
# step 2900: train loss 3.3163, val loss 3.2981
# step 2910: train loss 3.3210, val loss 3.3101
# step 2920: train loss 3.3334, val loss 3.3239
# step 2930: train loss 3.3412, val loss 3.3158
# step 2940: train loss 3.3086, val loss 3.2993
# step 2950: train loss 3.3005, val loss 3.2892
# step 2960: train loss 3.2671, val loss 3.3062
# step 2970: train loss 3.2815, val loss 3.2917
# step 2980: train loss 3.2876, val loss 3.2666
# step 2990: train loss 3.2827, val loss 3.2582
# step 3000: train loss 3.3002, val loss 3.2560
# step 3010: train loss 3.2664, val loss 3.2735
# step 3020: train loss 3.2619, val loss 3.2726
# step 3030: train loss 3.2780, val loss 3.2641
# step 3040: train loss 3.2674, val loss 3.2825
# step 3050: train loss 3.2418, val loss 3.2737
# step 3060: train loss 3.2614, val loss 3.2596
# step 3070: train loss 3.2479, val loss 3.2850
# step 3080: train loss 3.2579, val loss 3.2188
# step 3090: train loss 3.2593, val loss 3.2596
# step 3100: train loss 3.2473, val loss 3.2690
# step 3110: train loss 3.2227, val loss 3.2607
# step 3120: train loss 3.2426, val loss 3.2087
# step 3130: train loss 3.2617, val loss 3.2296
# step 3140: train loss 3.2126, val loss 3.1970
# step 3150: train loss 3.2447, val loss 3.2464
# step 3160: train loss 3.2225, val loss 3.2021
# step 3170: train loss 3.1917, val loss 3.2264
# step 3180: train loss 3.2347, val loss 3.2090
# step 3190: train loss 3.2122, val loss 3.2132
# step 3200: train loss 3.2129, val loss 3.2246
# step 3210: train loss 3.1808, val loss 3.2313
# step 3220: train loss 3.2134, val loss 3.2077
# step 3230: train loss 3.2254, val loss 3.2057
# step 3240: train loss 3.2139, val loss 3.2445
# step 3250: train loss 3.2216, val loss 3.2019
# step 3260: train loss 3.2408, val loss 3.1726
# step 3270: train loss 3.2048, val loss 3.1957
# step 3280: train loss 3.1782, val loss 3.2055
# step 3290: train loss 3.1819, val loss 3.2094
# step 3300: train loss 3.1931, val loss 3.1719
# step 3310: train loss 3.1916, val loss 3.2070
# step 3320: train loss 3.1767, val loss 3.1963
# step 3330: train loss 3.1673, val loss 3.2055
# step 3340: train loss 3.1874, val loss 3.1772
# step 3350: train loss 3.1696, val loss 3.1980
# step 3360: train loss 3.1633, val loss 3.1775
# step 3370: train loss 3.1746, val loss 3.1646
# step 3380: train loss 3.1884, val loss 3.1655
# step 3390: train loss 3.1652, val loss 3.1546
# step 3400: train loss 3.1938, val loss 3.1690
# step 3410: train loss 3.1741, val loss 3.1820
# step 3420: train loss 3.1637, val loss 3.1881
# step 3430: train loss 3.1804, val loss 3.1774
# step 3440: train loss 3.1528, val loss 3.1977
# step 3450: train loss 3.1621, val loss 3.1597
# step 3460: train loss 3.1535, val loss 3.1353
# step 3470: train loss 3.1657, val loss 3.1397
# step 3480: train loss 3.1258, val loss 3.1531
# step 3490: train loss 3.1165, val loss 3.1425
# step 3500: train loss 3.1128, val loss 3.1235
# step 3510: train loss 3.1248, val loss 3.1538
# step 3520: train loss 3.1117, val loss 3.1322
# step 3530: train loss 3.1089, val loss 3.1216
# step 3540: train loss 3.1345, val loss 3.1302
# step 3550: train loss 3.1027, val loss 3.1371
# step 3560: train loss 3.1321, val loss 3.1258
# step 3570: train loss 3.1215, val loss 3.1290
# step 3580: train loss 3.1132, val loss 3.1114
# step 3590: train loss 3.1055, val loss 3.1458
# step 3600: train loss 3.0981, val loss 3.1408
# step 3610: train loss 3.1034, val loss 3.1013
# step 3620: train loss 3.1157, val loss 3.1303
# step 3630: train loss 3.1014, val loss 3.1264
# step 3640: train loss 3.0952, val loss 3.1316
# step 3650: train loss 3.0861, val loss 3.1067
# step 3660: train loss 3.0988, val loss 3.0804
# step 3670: train loss 3.1113, val loss 3.1056
# step 3680: train loss 3.1129, val loss 3.1027
# step 3690: train loss 3.1043, val loss 3.0508
# step 3700: train loss 3.0955, val loss 3.1035
# step 3710: train loss 3.0547, val loss 3.1021
# step 3720: train loss 3.0763, val loss 3.0710
# step 3730: train loss 3.0793, val loss 3.0713
# step 3740: train loss 3.0903, val loss 3.0997
# step 3750: train loss 3.0573, val loss 3.0707
# step 3760: train loss 3.0604, val loss 3.0320
# step 3770: train loss 3.0829, val loss 3.0561
# step 3780: train loss 3.0695, val loss 3.0764
# step 3790: train loss 3.0772, val loss 3.0960
# step 3800: train loss 3.0780, val loss 3.0686
# step 3810: train loss 3.0900, val loss 3.0626
# step 3820: train loss 3.0632, val loss 3.0722
# step 3830: train loss 3.0830, val loss 3.0584
# step 3840: train loss 3.0469, val loss 3.0722
# step 3850: train loss 3.0479, val loss 3.0825
# step 3860: train loss 3.0522, val loss 3.0957
# step 3870: train loss 3.0383, val loss 3.0627
# step 3880: train loss 3.0289, val loss 3.0733
# step 3890: train loss 3.0383, val loss 3.0534
# step 3900: train loss 3.0168, val loss 3.0667
# step 3910: train loss 2.9999, val loss 3.0663
# step 3920: train loss 3.0419, val loss 3.0496
# step 3930: train loss 3.0291, val loss 3.0474
# step 3940: train loss 3.0092, val loss 3.0375
# step 3950: train loss 3.0292, val loss 3.0621
# step 3960: train loss 3.0241, val loss 3.0351
# step 3970: train loss 3.0282, val loss 3.0018
# step 3980: train loss 3.0281, val loss 3.0285
# step 3990: train loss 3.0187, val loss 3.0676
# step 4000: train loss 3.0252, val loss 3.0260
# step 4010: train loss 3.0274, val loss 3.0854
# step 4020: train loss 2.9914, val loss 3.0224
# step 4030: train loss 2.9948, val loss 3.0493
# step 4040: train loss 2.9880, val loss 3.0097
# step 4050: train loss 3.0171, val loss 3.0263
# step 4060: train loss 3.0176, val loss 3.0017
# step 4070: train loss 3.0045, val loss 3.0340
# step 4080: train loss 3.0153, val loss 2.9993
# step 4090: train loss 3.0033, val loss 3.0320
# step 4100: train loss 2.9738, val loss 3.0309
# step 4110: train loss 2.9648, val loss 2.9898
# step 4120: train loss 2.9808, val loss 3.0060
# step 4130: train loss 2.9915, val loss 3.0101
# step 4140: train loss 2.9795, val loss 2.9999
# step 4150: train loss 2.9690, val loss 2.9889
# step 4160: train loss 2.9844, val loss 3.0284
# step 4170: train loss 2.9917, val loss 3.0042
# step 4180: train loss 2.9524, val loss 2.9843
# step 4190: train loss 2.9895, val loss 3.0142
# step 4200: train loss 2.9712, val loss 2.9932
# step 4210: train loss 2.9662, val loss 2.9853
# step 4220: train loss 2.9564, val loss 3.0319
# step 4230: train loss 2.9465, val loss 2.9921
# step 4240: train loss 2.9669, val loss 3.0070
# step 4250: train loss 2.9722, val loss 2.9855
# step 4260: train loss 2.9595, val loss 3.0123
# step 4270: train loss 2.9904, val loss 2.9569
# step 4280: train loss 2.9582, val loss 2.9919
# step 4290: train loss 2.9554, val loss 3.0150
# step 4300: train loss 2.9422, val loss 2.9734
# step 4310: train loss 2.9521, val loss 2.9652
# step 4320: train loss 2.9793, val loss 2.9788
# step 4330: train loss 2.9508, val loss 2.9769
# step 4340: train loss 2.9608, val loss 3.0070
# step 4350: train loss 2.9597, val loss 2.9689
# step 4360: train loss 2.9292, val loss 2.9459
# step 4370: train loss 2.9289, val loss 3.0045
# step 4380: train loss 2.9504, val loss 2.9639
# step 4390: train loss 2.9454, val loss 2.9577
# step 4400: train loss 2.9179, val loss 2.9725
# step 4410: train loss 2.9163, val loss 2.9346
# step 4420: train loss 2.9400, val loss 2.9810
# step 4430: train loss 2.9287, val loss 2.9713
# step 4440: train loss 2.9405, val loss 2.9019
# step 4450: train loss 2.9246, val loss 2.9379
# step 4460: train loss 2.9156, val loss 2.9671
# step 4470: train loss 2.9089, val loss 2.9698
# step 4480: train loss 2.9061, val loss 2.9502
# step 4490: train loss 2.9301, val loss 2.9586
# step 4500: train loss 2.9196, val loss 2.9364
# step 4510: train loss 2.9210, val loss 2.9710
# step 4520: train loss 2.9352, val loss 2.9495
# step 4530: train loss 2.9332, val loss 2.9589
# step 4540: train loss 2.9010, val loss 2.9389
# step 4550: train loss 2.9203, val loss 2.8828
# step 4560: train loss 2.9059, val loss 2.9324
# step 4570: train loss 2.9126, val loss 2.9356
# step 4580: train loss 2.8941, val loss 2.9424
# step 4590: train loss 2.9042, val loss 2.9367
# step 4600: train loss 2.9122, val loss 2.9434
# step 4610: train loss 2.9352, val loss 2.9104
# step 4620: train loss 2.8811, val loss 2.9094
# step 4630: train loss 2.8948, val loss 2.9215
# step 4640: train loss 2.8829, val loss 2.9309
# step 4650: train loss 2.8851, val loss 2.9233
# step 4660: train loss 2.8879, val loss 2.9251
# step 4670: train loss 2.8684, val loss 2.8991
# step 4680: train loss 2.9185, val loss 2.9292
# step 4690: train loss 2.8711, val loss 2.9389
# step 4700: train loss 2.8662, val loss 2.9053
# step 4710: train loss 2.8676, val loss 2.8969
# step 4720: train loss 2.8843, val loss 2.9008
# step 4730: train loss 2.8902, val loss 2.8799
# step 4740: train loss 2.8929, val loss 2.9171
# step 4750: train loss 2.8785, val loss 2.9290
# step 4760: train loss 2.8792, val loss 2.8806
# step 4770: train loss 2.8891, val loss 2.9051
# step 4780: train loss 2.9035, val loss 2.8964
# step 4790: train loss 2.8624, val loss 2.9274
# step 4800: train loss 2.8606, val loss 2.9069
# step 4810: train loss 2.8650, val loss 2.8878
# step 4820: train loss 2.8702, val loss 2.9108
# step 4830: train loss 2.8587, val loss 2.9097
# step 4840: train loss 2.8257, val loss 2.9065
# step 4850: train loss 2.8478, val loss 2.8825
# step 4860: train loss 2.8641, val loss 2.8789
# step 4870: train loss 2.8430, val loss 2.8905
# step 4880: train loss 2.8761, val loss 2.8990
# step 4890: train loss 2.8832, val loss 2.8724
# step 4900: train loss 2.8403, val loss 2.8914
# step 4910: train loss 2.8595, val loss 2.9130
# step 4920: train loss 2.8585, val loss 2.8900
# step 4930: train loss 2.8494, val loss 2.8841
# step 4940: train loss 2.8441, val loss 2.9042
# step 4950: train loss 2.8609, val loss 2.8639
# step 4960: train loss 2.8326, val loss 2.8982
# step 4970: train loss 2.8349, val loss 2.8548
# step 4980: train loss 2.8216, val loss 2.8748
# step 4990: train loss 2.8516, val loss 2.8665
# step 5000: train loss 2.8146, val loss 2.8695
# step 5010: train loss 2.8335, val loss 2.8811
# step 5020: train loss 2.8434, val loss 2.8853
# step 5030: train loss 2.8254, val loss 2.8449
# step 5040: train loss 2.8130, val loss 2.8520
# step 5050: train loss 2.8161, val loss 2.8402
# step 5060: train loss 2.8171, val loss 2.8799
# step 5070: train loss 2.8662, val loss 2.8707
# step 5080: train loss 2.8394, val loss 2.8840
# step 5090: train loss 2.8362, val loss 2.8460
# step 5100: train loss 2.8641, val loss 2.8480
# step 5110: train loss 2.8407, val loss 2.9083
# step 5120: train loss 2.8076, val loss 2.8505
# step 5130: train loss 2.8262, val loss 2.8548
# step 5140: train loss 2.7957, val loss 2.8783
# step 5150: train loss 2.7916, val loss 2.8607
# step 5160: train loss 2.8191, val loss 2.8524
# step 5170: train loss 2.8190, val loss 2.8588
# step 5180: train loss 2.8226, val loss 2.8636
# step 5190: train loss 2.8099, val loss 2.8204
# step 5200: train loss 2.7974, val loss 2.8481
# step 5210: train loss 2.8071, val loss 2.7972
# step 5220: train loss 2.7847, val loss 2.8534
# step 5230: train loss 2.7917, val loss 2.8289
# step 5240: train loss 2.8000, val loss 2.8101
# step 5250: train loss 2.8261, val loss 2.8261
# step 5260: train loss 2.7978, val loss 2.8172
# step 5270: train loss 2.8019, val loss 2.8128
# step 5280: train loss 2.8161, val loss 2.8274
# step 5290: train loss 2.7846, val loss 2.8327
# step 5300: train loss 2.8156, val loss 2.8152
# step 5310: train loss 2.8023, val loss 2.8393
# step 5320: train loss 2.8204, val loss 2.8187
# step 5330: train loss 2.7713, val loss 2.8176
# step 5340: train loss 2.8127, val loss 2.8039
# step 5350: train loss 2.7867, val loss 2.8128
# step 5360: train loss 2.7920, val loss 2.8298
# step 5370: train loss 2.8058, val loss 2.8393
# step 5380: train loss 2.7671, val loss 2.8232
# step 5390: train loss 2.7848, val loss 2.8429
# step 5400: train loss 2.7894, val loss 2.8082
# step 5410: train loss 2.7560, val loss 2.8054
# step 5420: train loss 2.7894, val loss 2.7974
# step 5430: train loss 2.7658, val loss 2.8295
# step 5440: train loss 2.7752, val loss 2.8156
# step 5450: train loss 2.7349, val loss 2.8162
# step 5460: train loss 2.7780, val loss 2.8288
# step 5470: train loss 2.8102, val loss 2.8335
# step 5480: train loss 2.7461, val loss 2.8477
# step 5490: train loss 2.7945, val loss 2.8018
# step 5500: train loss 2.7705, val loss 2.7992
# step 5510: train loss 2.7729, val loss 2.7947
# step 5520: train loss 2.7768, val loss 2.8224
# step 5530: train loss 2.7514, val loss 2.7637
# step 5540: train loss 2.7689, val loss 2.8021
# step 5550: train loss 2.7757, val loss 2.7606
# step 5560: train loss 2.7742, val loss 2.8225
# step 5570: train loss 2.7603, val loss 2.7712
# step 5580: train loss 2.7620, val loss 2.7792
# step 5590: train loss 2.7483, val loss 2.8196
# step 5600: train loss 2.7341, val loss 2.7692
# step 5610: train loss 2.7603, val loss 2.8058
# step 5620: train loss 2.7785, val loss 2.7973
# step 5630: train loss 2.7707, val loss 2.8003
# step 5640: train loss 2.7524, val loss 2.7707
# step 5650: train loss 2.7661, val loss 2.7752
# step 5660: train loss 2.7573, val loss 2.7375
# step 5670: train loss 2.7662, val loss 2.7919
# step 5680: train loss 2.7482, val loss 2.7814
# step 5690: train loss 2.7434, val loss 2.7828
# step 5700: train loss 2.7536, val loss 2.7811
# step 5710: train loss 2.7560, val loss 2.7686
# step 5720: train loss 2.7539, val loss 2.7992
# step 5730: train loss 2.7226, val loss 2.7939
# step 5740: train loss 2.7393, val loss 2.7566
# step 5750: train loss 2.7606, val loss 2.8038
# step 5760: train loss 2.7369, val loss 2.7420
# step 5770: train loss 2.7357, val loss 2.7948
# step 5780: train loss 2.7499, val loss 2.8034
# step 5790: train loss 2.7304, val loss 2.8081
# step 5800: train loss 2.7321, val loss 2.8130
# step 5810: train loss 2.7226, val loss 2.7581
# step 5820: train loss 2.7372, val loss 2.7581
# step 5830: train loss 2.7732, val loss 2.8072
# step 5840: train loss 2.7384, val loss 2.7926
# step 5850: train loss 2.7533, val loss 2.7627
# step 5860: train loss 2.6999, val loss 2.7670
# step 5870: train loss 2.7377, val loss 2.7327
# step 5880: train loss 2.7273, val loss 2.7881
# step 5890: train loss 2.7237, val loss 2.7512
# step 5900: train loss 2.7193, val loss 2.7489
# step 5910: train loss 2.7253, val loss 2.7603
# step 5920: train loss 2.7188, val loss 2.7550
# step 5930: train loss 2.7109, val loss 2.7537
# step 5940: train loss 2.7259, val loss 2.7859
# step 5950: train loss 2.7143, val loss 2.7702
# step 5960: train loss 2.7164, val loss 2.7561
# step 5970: train loss 2.7153, val loss 2.7901
# step 5980: train loss 2.7216, val loss 2.7791
# step 5990: train loss 2.7108, val loss 2.7670
# step 6000: train loss 2.7096, val loss 2.7776
# step 6010: train loss 2.7276, val loss 2.7456
# step 6020: train loss 2.7159, val loss 2.7673
# step 6030: train loss 2.6962, val loss 2.7665
# step 6040: train loss 2.7210, val loss 2.7827
# step 6050: train loss 2.7046, val loss 2.7328
# step 6060: train loss 2.7286, val loss 2.8025
# step 6070: train loss 2.7321, val loss 2.7922
# step 6080: train loss 2.7314, val loss 2.7385
# step 6090: train loss 2.7084, val loss 2.7894
# step 6100: train loss 2.6995, val loss 2.7673
# step 6110: train loss 2.7023, val loss 2.7363
# step 6120: train loss 2.6836, val loss 2.7128
# step 6130: train loss 2.6722, val loss 2.7124
# step 6140: train loss 2.6892, val loss 2.7353
# step 6150: train loss 2.7215, val loss 2.7372
# step 6160: train loss 2.7181, val loss 2.7353
# step 6170: train loss 2.7057, val loss 2.7560
# step 6180: train loss 2.7208, val loss 2.7393
# step 6190: train loss 2.6968, val loss 2.7651
# step 6200: train loss 2.7078, val loss 2.7580
# step 6210: train loss 2.7010, val loss 2.7302
# step 6220: train loss 2.7039, val loss 2.7681
# step 6230: train loss 2.6991, val loss 2.7315
# step 6240: train loss 2.6697, val loss 2.7529
# step 6250: train loss 2.7062, val loss 2.7397
# step 6260: train loss 2.7018, val loss 2.7490
# step 6270: train loss 2.7036, val loss 2.7371
# step 6280: train loss 2.6647, val loss 2.7323
# step 6290: train loss 2.6964, val loss 2.7362
# step 6300: train loss 2.6751, val loss 2.7481
# step 6310: train loss 2.6804, val loss 2.7532
# step 6320: train loss 2.7136, val loss 2.7362
# step 6330: train loss 2.6630, val loss 2.7295
# step 6340: train loss 2.6749, val loss 2.7340
# step 6350: train loss 2.7028, val loss 2.7343
# step 6360: train loss 2.6699, val loss 2.7568
# step 6370: train loss 2.6771, val loss 2.6966
# step 6380: train loss 2.6819, val loss 2.7431
# step 6390: train loss 2.6553, val loss 2.7023
# step 6400: train loss 2.6624, val loss 2.6894
# step 6410: train loss 2.6685, val loss 2.7259
# step 6420: train loss 2.6733, val loss 2.7639
# step 6430: train loss 2.6809, val loss 2.7257
# step 6440: train loss 2.6686, val loss 2.7293
# step 6450: train loss 2.6965, val loss 2.7079
# step 6460: train loss 2.6616, val loss 2.7329
# step 6470: train loss 2.6845, val loss 2.6985
# step 6480: train loss 2.7005, val loss 2.7088
# step 6490: train loss 2.6513, val loss 2.6829
# step 6500: train loss 2.6804, val loss 2.7173
# step 6510: train loss 2.6614, val loss 2.7306
# step 6520: train loss 2.6753, val loss 2.7398
# step 6530: train loss 2.6704, val loss 2.7340
# step 6540: train loss 2.6760, val loss 2.7433
# step 6550: train loss 2.6733, val loss 2.7403
# step 6560: train loss 2.6542, val loss 2.7285
# step 6570: train loss 2.6735, val loss 2.7330
# step 6580: train loss 2.6627, val loss 2.7344
# step 6590: train loss 2.6596, val loss 2.7465
# step 6600: train loss 2.6308, val loss 2.6877
# step 6610: train loss 2.6723, val loss 2.7352
# step 6620: train loss 2.6780, val loss 2.6790
# step 6630: train loss 2.6533, val loss 2.6867
# step 6640: train loss 2.6344, val loss 2.6821
# step 6650: train loss 2.6775, val loss 2.6962
# step 6660: train loss 2.6463, val loss 2.6997
# step 6670: train loss 2.6776, val loss 2.7197
# step 6680: train loss 2.6607, val loss 2.7290
# step 6690: train loss 2.6689, val loss 2.7047
# step 6700: train loss 2.6376, val loss 2.7123
# step 6710: train loss 2.6511, val loss 2.7075
# step 6720: train loss 2.6561, val loss 2.6760
# step 6730: train loss 2.6698, val loss 2.7331
# step 6740: train loss 2.6657, val loss 2.7312
# step 6750: train loss 2.6791, val loss 2.6721
# step 6760: train loss 2.6534, val loss 2.7324
# step 6770: train loss 2.6498, val loss 2.6860
# step 6780: train loss 2.6675, val loss 2.6839
# step 6790: train loss 2.6272, val loss 2.7215
# step 6800: train loss 2.6261, val loss 2.7073
# step 6810: train loss 2.6286, val loss 2.6770
# step 6820: train loss 2.6208, val loss 2.7483
# step 6830: train loss 2.6502, val loss 2.6855
# step 6840: train loss 2.6562, val loss 2.7048
# step 6850: train loss 2.6582, val loss 2.6891
# step 6860: train loss 2.6530, val loss 2.6987
# step 6870: train loss 2.6391, val loss 2.7060
# step 6880: train loss 2.6332, val loss 2.6766
# step 6890: train loss 2.6436, val loss 2.6974
# step 6900: train loss 2.6341, val loss 2.7070
# step 6910: train loss 2.6391, val loss 2.7046
# step 6920: train loss 2.6524, val loss 2.6548
# step 6930: train loss 2.6561, val loss 2.7040
# step 6940: train loss 2.6189, val loss 2.7105
# step 6950: train loss 2.6333, val loss 2.7331
# step 6960: train loss 2.6296, val loss 2.6788
# step 6970: train loss 2.6408, val loss 2.6713
# step 6980: train loss 2.6358, val loss 2.6817
# step 6990: train loss 2.6077, val loss 2.7150
# step 7000: train loss 2.6212, val loss 2.6746
# step 7010: train loss 2.6111, val loss 2.6781
# step 7020: train loss 2.6529, val loss 2.6670
# step 7030: train loss 2.6421, val loss 2.6945
# step 7040: train loss 2.6154, val loss 2.7166
# step 7050: train loss 2.6216, val loss 2.6949
# step 7060: train loss 2.6005, val loss 2.6875
# step 7070: train loss 2.6301, val loss 2.7017
# step 7080: train loss 2.6437, val loss 2.6801
# step 7090: train loss 2.6323, val loss 2.6736
# step 7100: train loss 2.6327, val loss 2.7052
# step 7110: train loss 2.6544, val loss 2.6905
# step 7120: train loss 2.6048, val loss 2.6677
# step 7130: train loss 2.6412, val loss 2.6756
# step 7140: train loss 2.6012, val loss 2.6977
# step 7150: train loss 2.6436, val loss 2.6890
# step 7160: train loss 2.6228, val loss 2.6638
# step 7170: train loss 2.6211, val loss 2.7150
# step 7180: train loss 2.6023, val loss 2.6839
# step 7190: train loss 2.6110, val loss 2.6606
# step 7200: train loss 2.6022, val loss 2.6933
# step 7210: train loss 2.6021, val loss 2.6736
# step 7220: train loss 2.5906, val loss 2.7155
# step 7230: train loss 2.6230, val loss 2.7131
# step 7240: train loss 2.6199, val loss 2.6852
# step 7250: train loss 2.6303, val loss 2.6585
# step 7260: train loss 2.5760, val loss 2.6749
# step 7270: train loss 2.6000, val loss 2.7009
# step 7280: train loss 2.6198, val loss 2.6982
# step 7290: train loss 2.6166, val loss 2.6680
# step 7300: train loss 2.6061, val loss 2.7089
# step 7310: train loss 2.6217, val loss 2.6741
# step 7320: train loss 2.6054, val loss 2.6879
# step 7330: train loss 2.6448, val loss 2.6613
# step 7340: train loss 2.6347, val loss 2.6852
# step 7350: train loss 2.6185, val loss 2.6533
# step 7360: train loss 2.6193, val loss 2.6767
# step 7370: train loss 2.6111, val loss 2.6815
# step 7380: train loss 2.6178, val loss 2.6645
# step 7390: train loss 2.6062, val loss 2.6566
# step 7400: train loss 2.5939, val loss 2.6639
# step 7410: train loss 2.6221, val loss 2.6786
# step 7420: train loss 2.6189, val loss 2.6781
# step 7430: train loss 2.6263, val loss 2.6916
# step 7440: train loss 2.6016, val loss 2.6624
# step 7450: train loss 2.6062, val loss 2.6687
# step 7460: train loss 2.6074, val loss 2.6534
# step 7470: train loss 2.6064, val loss 2.6411
# step 7480: train loss 2.6049, val loss 2.6268
# step 7490: train loss 2.5897, val loss 2.6741
# step 7500: train loss 2.6201, val loss 2.6972
# step 7510: train loss 2.6294, val loss 2.6438
# step 7520: train loss 2.6295, val loss 2.6340
# step 7530: train loss 2.5827, val loss 2.6548
# step 7540: train loss 2.5988, val loss 2.6646
# step 7550: train loss 2.5889, val loss 2.6740
# step 7560: train loss 2.5907, val loss 2.6855
# step 7570: train loss 2.6066, val loss 2.6716
# step 7580: train loss 2.5984, val loss 2.6209
# step 7590: train loss 2.5915, val loss 2.6169
# step 7600: train loss 2.5865, val loss 2.6372
# step 7610: train loss 2.5835, val loss 2.6367
# step 7620: train loss 2.5979, val loss 2.6747
# step 7630: train loss 2.5967, val loss 2.6818
# step 7640: train loss 2.6190, val loss 2.6808
# step 7650: train loss 2.6134, val loss 2.6467
# step 7660: train loss 2.5784, val loss 2.6704
# step 7670: train loss 2.6014, val loss 2.6506
# step 7680: train loss 2.5799, val loss 2.6261
# step 7690: train loss 2.5735, val loss 2.6507
# step 7700: train loss 2.6025, val loss 2.6641
# step 7710: train loss 2.5981, val loss 2.6501
# step 7720: train loss 2.5818, val loss 2.6687
# step 7730: train loss 2.6005, val loss 2.6598
# step 7740: train loss 2.5936, val loss 2.6513
# step 7750: train loss 2.5833, val loss 2.6452
# step 7760: train loss 2.5664, val loss 2.6447
# step 7770: train loss 2.5906, val loss 2.6750
# step 7780: train loss 2.5830, val loss 2.6615
# step 7790: train loss 2.6001, val loss 2.6253
# step 7800: train loss 2.6032, val loss 2.6286
# step 7810: train loss 2.5679, val loss 2.6499
# step 7820: train loss 2.5678, val loss 2.6317
# step 7830: train loss 2.5910, val loss 2.6398
# step 7840: train loss 2.5900, val loss 2.6369
# step 7850: train loss 2.6136, val loss 2.6130
# step 7860: train loss 2.5907, val loss 2.6457
# step 7870: train loss 2.5935, val loss 2.6496
# step 7880: train loss 2.6036, val loss 2.6520
# step 7890: train loss 2.5903, val loss 2.6536
# step 7900: train loss 2.5859, val loss 2.6317
# step 7910: train loss 2.5961, val loss 2.6569
# step 7920: train loss 2.5930, val loss 2.6413
# step 7930: train loss 2.5922, val loss 2.6276
# step 7940: train loss 2.5704, val loss 2.6152
# step 7950: train loss 2.5900, val loss 2.6497
# step 7960: train loss 2.5613, val loss 2.6498
# step 7970: train loss 2.5843, val loss 2.6269
# step 7980: train loss 2.5775, val loss 2.6254
# step 7990: train loss 2.5822, val loss 2.6447
# step 8000: train loss 2.5651, val loss 2.6379
# step 8010: train loss 2.5594, val loss 2.6480
# step 8020: train loss 2.5681, val loss 2.6217
# step 8030: train loss 2.5676, val loss 2.6164
# step 8040: train loss 2.5866, val loss 2.6112
# step 8050: train loss 2.5838, val loss 2.6080
# step 8060: train loss 2.5676, val loss 2.6250
# step 8070: train loss 2.5763, val loss 2.6526
# step 8080: train loss 2.5658, val loss 2.6196
# step 8090: train loss 2.6003, val loss 2.6313
# step 8100: train loss 2.5503, val loss 2.6325
# step 8110: train loss 2.5872, val loss 2.6398
# step 8120: train loss 2.5683, val loss 2.6242
# step 8130: train loss 2.5659, val loss 2.6521
# step 8140: train loss 2.5682, val loss 2.6201
# step 8150: train loss 2.5813, val loss 2.6060
# step 8160: train loss 2.5751, val loss 2.6373
# step 8170: train loss 2.5738, val loss 2.6083
# step 8180: train loss 2.5907, val loss 2.6001
# step 8190: train loss 2.5641, val loss 2.6451
# step 8200: train loss 2.5840, val loss 2.6497
# step 8210: train loss 2.5852, val loss 2.6391
# step 8220: train loss 2.5627, val loss 2.6187
# step 8230: train loss 2.5835, val loss 2.6157
# step 8240: train loss 2.5825, val loss 2.6434
# step 8250: train loss 2.5431, val loss 2.6319
# step 8260: train loss 2.5633, val loss 2.6449
# step 8270: train loss 2.5671, val loss 2.6034
# step 8280: train loss 2.5504, val loss 2.6452
# step 8290: train loss 2.5672, val loss 2.6306
# step 8300: train loss 2.5814, val loss 2.6272
# step 8310: train loss 2.5720, val loss 2.6505
# step 8320: train loss 2.5610, val loss 2.6029
# step 8330: train loss 2.5615, val loss 2.6225
# step 8340: train loss 2.5589, val loss 2.6031
# step 8350: train loss 2.5414, val loss 2.6299
# step 8360: train loss 2.5685, val loss 2.6360
# step 8370: train loss 2.5890, val loss 2.6208
# step 8380: train loss 2.5514, val loss 2.5626
# step 8390: train loss 2.5639, val loss 2.6314
# step 8400: train loss 2.5527, val loss 2.6588
# step 8410: train loss 2.5788, val loss 2.6410
# step 8420: train loss 2.5391, val loss 2.6158
# step 8430: train loss 2.5555, val loss 2.6190
# step 8440: train loss 2.5518, val loss 2.6493
# step 8450: train loss 2.5440, val loss 2.6101
# step 8460: train loss 2.5654, val loss 2.6064
# step 8470: train loss 2.5514, val loss 2.6026
# step 8480: train loss 2.5601, val loss 2.6244
# step 8490: train loss 2.5616, val loss 2.6336
# step 8500: train loss 2.5689, val loss 2.5874
# step 8510: train loss 2.5508, val loss 2.5897
# step 8520: train loss 2.5472, val loss 2.6432
# step 8530: train loss 2.5259, val loss 2.6681
# step 8540: train loss 2.5301, val loss 2.5993
# step 8550: train loss 2.5727, val loss 2.6456
# step 8560: train loss 2.5527, val loss 2.6033
# step 8570: train loss 2.5631, val loss 2.6111
# step 8580: train loss 2.5364, val loss 2.6003
# step 8590: train loss 2.5430, val loss 2.6451
# step 8600: train loss 2.5686, val loss 2.5921
# step 8610: train loss 2.5339, val loss 2.5990
# step 8620: train loss 2.5522, val loss 2.6009
# step 8630: train loss 2.5412, val loss 2.6272
# step 8640: train loss 2.5578, val loss 2.6037
# step 8650: train loss 2.5166, val loss 2.6317
# step 8660: train loss 2.5430, val loss 2.6486
# step 8670: train loss 2.5638, val loss 2.6324
# step 8680: train loss 2.5652, val loss 2.6112
# step 8690: train loss 2.5646, val loss 2.5963
# step 8700: train loss 2.5471, val loss 2.6222
# step 8710: train loss 2.5534, val loss 2.6047
# step 8720: train loss 2.5536, val loss 2.6159
# step 8730: train loss 2.5653, val loss 2.6243
# step 8740: train loss 2.5399, val loss 2.6361
# step 8750: train loss 2.5333, val loss 2.6265
# step 8760: train loss 2.5260, val loss 2.6365
# step 8770: train loss 2.5640, val loss 2.5826
# step 8780: train loss 2.5545, val loss 2.6123
# step 8790: train loss 2.5526, val loss 2.6020
# step 8800: train loss 2.5534, val loss 2.5917
# step 8810: train loss 2.5640, val loss 2.5782
# step 8820: train loss 2.5353, val loss 2.6140
# step 8830: train loss 2.5314, val loss 2.5565
# step 8840: train loss 2.5452, val loss 2.6023
# step 8850: train loss 2.5580, val loss 2.5952
# step 8860: train loss 2.5368, val loss 2.6056
# step 8870: train loss 2.5525, val loss 2.5930
# step 8880: train loss 2.5339, val loss 2.6109
# step 8890: train loss 2.5441, val loss 2.6038
# step 8900: train loss 2.5516, val loss 2.6068
# step 8910: train loss 2.5356, val loss 2.6235
# step 8920: train loss 2.5549, val loss 2.5740
# step 8930: train loss 2.5531, val loss 2.5985
# step 8940: train loss 2.5444, val loss 2.6305
# step 8950: train loss 2.5566, val loss 2.5813
# step 8960: train loss 2.5304, val loss 2.5893
# step 8970: train loss 2.5383, val loss 2.5910
# step 8980: train loss 2.5295, val loss 2.5987
# step 8990: train loss 2.5540, val loss 2.5722
# step 9000: train loss 2.5272, val loss 2.5898
# step 9010: train loss 2.5575, val loss 2.6164
# step 9020: train loss 2.5345, val loss 2.6214
# step 9030: train loss 2.5272, val loss 2.5820
# step 9040: train loss 2.5348, val loss 2.6078
# step 9050: train loss 2.5391, val loss 2.5750
# step 9060: train loss 2.5583, val loss 2.6064
# step 9070: train loss 2.5039, val loss 2.5933
# step 9080: train loss 2.5331, val loss 2.5841
# step 9090: train loss 2.5330, val loss 2.6072
# step 9100: train loss 2.5356, val loss 2.5784
# step 9110: train loss 2.5315, val loss 2.6098
# step 9120: train loss 2.5056, val loss 2.6125
# step 9130: train loss 2.5402, val loss 2.5641
# step 9140: train loss 2.5382, val loss 2.5900
# step 9150: train loss 2.5284, val loss 2.5933
# step 9160: train loss 2.5306, val loss 2.6015
# step 9170: train loss 2.5609, val loss 2.5872
# step 9180: train loss 2.5238, val loss 2.5664
# step 9190: train loss 2.5657, val loss 2.5796
# step 9200: train loss 2.5217, val loss 2.5794
# step 9210: train loss 2.5353, val loss 2.5672
# step 9220: train loss 2.5132, val loss 2.5774
# step 9230: train loss 2.5388, val loss 2.5872
# step 9240: train loss 2.5362, val loss 2.5869
# step 9250: train loss 2.5223, val loss 2.6041
# step 9260: train loss 2.5000, val loss 2.5912
# step 9270: train loss 2.5275, val loss 2.5863
# step 9280: train loss 2.5482, val loss 2.5733
# step 9290: train loss 2.5279, val loss 2.6006
# step 9300: train loss 2.5326, val loss 2.6140
# step 9310: train loss 2.5438, val loss 2.6041
# step 9320: train loss 2.5345, val loss 2.5943
# step 9330: train loss 2.5287, val loss 2.5641
# step 9340: train loss 2.5047, val loss 2.6025
# step 9350: train loss 2.5122, val loss 2.6232
# step 9360: train loss 2.5188, val loss 2.5747
# step 9370: train loss 2.5359, val loss 2.5722
# step 9380: train loss 2.4931, val loss 2.6057
# step 9390: train loss 2.5347, val loss 2.5707
# step 9400: train loss 2.5428, val loss 2.6218
# step 9410: train loss 2.5392, val loss 2.6097
# step 9420: train loss 2.5242, val loss 2.5891
# step 9430: train loss 2.5139, val loss 2.6132
# step 9440: train loss 2.5376, val loss 2.5895
# step 9450: train loss 2.5263, val loss 2.6068
# step 9460: train loss 2.5180, val loss 2.5893
# step 9470: train loss 2.5015, val loss 2.5658
# step 9480: train loss 2.5109, val loss 2.6276
# step 9490: train loss 2.5161, val loss 2.5886
# step 9500: train loss 2.5138, val loss 2.5678
# step 9510: train loss 2.5175, val loss 2.5952
# step 9520: train loss 2.5014, val loss 2.5877
# step 9530: train loss 2.4977, val loss 2.5519
# step 9540: train loss 2.5311, val loss 2.6179
# step 9550: train loss 2.5244, val loss 2.5907
# step 9560: train loss 2.5339, val loss 2.5884
# step 9570: train loss 2.5137, val loss 2.5950
# step 9580: train loss 2.5203, val loss 2.5863
# step 9590: train loss 2.5101, val loss 2.5907
# step 9600: train loss 2.5263, val loss 2.5755
# step 9610: train loss 2.5081, val loss 2.5777
# step 9620: train loss 2.5084, val loss 2.5960
# step 9630: train loss 2.5238, val loss 2.5962
# step 9640: train loss 2.5147, val loss 2.5649
# step 9650: train loss 2.5043, val loss 2.5708
# step 9660: train loss 2.5211, val loss 2.5836
# step 9670: train loss 2.5278, val loss 2.5686
# step 9680: train loss 2.5329, val loss 2.5729
# step 9690: train loss 2.5008, val loss 2.5865
# step 9700: train loss 2.5289, val loss 2.5912
# step 9710: train loss 2.5013, val loss 2.5550
# step 9720: train loss 2.5148, val loss 2.5637
# step 9730: train loss 2.5199, val loss 2.5763
# step 9740: train loss 2.5073, val loss 2.5814
# step 9750: train loss 2.5376, val loss 2.5776
# step 9760: train loss 2.5035, val loss 2.5733
# step 9770: train loss 2.5135, val loss 2.5584
# step 9780: train loss 2.5207, val loss 2.5485
# step 9790: train loss 2.4984, val loss 2.5830
# step 9800: train loss 2.5264, val loss 2.5770
# step 9810: train loss 2.5024, val loss 2.5739
# step 9820: train loss 2.4807, val loss 2.6024
# step 9830: train loss 2.5005, val loss 2.5705
# step 9840: train loss 2.4990, val loss 2.5636
# step 9850: train loss 2.5346, val loss 2.5637
# step 9860: train loss 2.5095, val loss 2.5849
# step 9870: train loss 2.5096, val loss 2.5689
# step 9880: train loss 2.4938, val loss 2.5660
# step 9890: train loss 2.5091, val loss 2.5864
# step 9900: train loss 2.5060, val loss 2.6002
# step 9910: train loss 2.5006, val loss 2.6168
# step 9920: train loss 2.5130, val loss 2.5884
# step 9930: train loss 2.5110, val loss 2.5350
# step 9940: train loss 2.5160, val loss 2.5802
# step 9950: train loss 2.4903, val loss 2.5610
# step 9960: train loss 2.5229, val loss 2.5688
# step 9970: train loss 2.5099, val loss 2.5611
# step 9980: train loss 2.4935, val loss 2.5638
# step 9990: train loss 2.5241, val loss 2.5723

# %% [markdown]
# Once the network has been trained for 100 iterations, we can generate a sequence of characters.
#
# #### Questions:
# - What is the effect of training?
# - Increase the number of iterations to 1,000 and then to 10,000. Note the obtained loss and the generated sentence. What do you observe?

# %%
idx = (torch.ones((1,1), dtype=torch.long)*3).to(device)
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# INGr?ÂÆÆÎXzoet Re mudôW4HuntAa   le bégaious je su.
#  pt z _j3:8UOTuvavou-INeufobe t,
# R7Âmmprs je de

# %% [markdown]
# **Comment**:
#
# - 100 iters: val loss ≃ 4.93, the generated sequence does not ressemble natural language.
#
# - 1k iters: val loss ≃ 4.27, the output remains incoherent.
#
# - 10k iters: val loss ≃ 2.55, the generated sequence begins to include a few recognizable words.
#
# - 25k iters: val loss ≃ 2.48 and the output does not seem better, the model has clearly reached a plateau where additional training ceases to improve performance.
#
#
# This confirms that relying only on the previous character is insufficient for meaningful text generation. The model lacks any real understanding of vocabulary or grammar. It cannot distinguish whether a character appears in the middle or end of a word (hence, if it will be followed by a letter or a space) or whether a word appears in the middle or end of a sentence (hence, if it will be followed by another word or a punctuation sign).

# %% [markdown]
# ## Single Head Attention
#
# We will now implement the basic attention mechanism. For each pair of words in the sequence, this mechanism combines:
# - **Q** (*query*): the information being searched for,
# - **K** (*key*): the information retrieved,
# - **V** (*value*): a result vector calculated from the attention mechanism.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masking
#
# However, since we are using the model to generate sequences, we must not use characters that come after the current character—these are precisely the characters we aim to predict during training. *The future should not be used to predict the future.*
#
# To enforce this constraint, we integrate a **masking matrix** into the process. This matrix ensures that:
# - For the first character in the sequence, only that character is available for prediction (no context).
# - For the second character, only the first and second characters can be used.
# - For the third character, only the first three characters are accessible, and so on.
#
# This results in a **lower triangular matrix**, where each row is normalized (rows sum to 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# The [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) function provides another way to achieve normalization.
#
# #### Question:
# - Verify that applying `softmax` results in the same lower triangular matrix.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# **Comment**:
# The first approach is an explicit normalization, by setting the sum of weights to 1. The second approach is an implicit normalization through the softmaw function. Their results are identitcal.

# %% [markdown]
# ### Implementation
#
# We can now implement the attention layer based on the following formula:
#
# ![attention_formula](images/attention_formula.png)
#
# This involves computing the **queries (Q)**, **keys (K)**, and **values (V)**, applying the **masking mechanism**, and using the **softmax function** to normalize the attention scores before computing the weighted sum of values.

# %% [markdown]
# #### Questions:
#
# - Create the **key**, **query**, and **value** layers as linear layers of dimension `C × head_size`.
# - Apply these layers to `x`.
# - Compute the attention weights:
#   ```python
#   weights = query @ key.transpose(-2, -1)
#   ```
#   (Transpose the second and third dimensions of `key` to enable matrix multiplication).
# - Apply the **normalization factor** (typically, divide by `sqrt(head_size)`).
# - Apply the **triangular mask** and the **softmax** function to `weights`.
# - Apply the **value** layer to `x`.
# - Compute the final output:
#   ```python
#   out = weights @ value(x)
#   ```

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)
## YOUR CODE HERE
# define the Key layer  
key = nn.Linear(C, head_size, bias=False)
# define the Query layer
query = nn.Linear(C, head_size, bias=False)
# define the Value layer
value =  nn.Linear(C, head_size, bias=False)
# apply each layer to the input
k = key(x) # (B, T, head_size)
q = query(x) # (B, T, head_size)
v = value(x) # (B, T, head_size)
# compute the normalize product between Q and K 
weights = q @ k.transpose(-2, -1) # (B, T, head_size) @ (B, 16, head_size) -> (B, T, T)
weights = weights / torch.sqrt(torch.tensor(head_size, dtype=torch.float32))
# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = weights.masked_fill(tril== 0, float('-inf'))
# apply the softmax
weights = torch.nn.functional.softmax(weights, dim=-1)
###
out = weights @ value(x) # (B, T, head_size)

# print the result
weights[0]
out[0]
# Out:
# tensor([[ 0.3660,  0.2275,  0.5257,  0.3053,  0.2234, -0.4510,  0.7561, -0.2748,
#          -0.8599,  0.1148,  0.1721, -0.2509, -0.6894,  0.3204, -0.5052, -0.4807],
#         [ 0.1473, -0.3983, -0.1496,  0.2605,  0.1749,  0.2319,  0.1575, -0.3194,
#           0.1460,  0.0083, -0.1718,  0.2255, -0.5690, -0.3850, -0.7705,  0.0130],
#         [ 0.2158, -0.0102, -0.6661,  0.1894, -0.3346, -0.0312,  0.4195,  0.2861,
#          -0.0280, -0.5017,  0.5267, -0.0024, -0.3089, -0.2563, -0.4188, -0.0914],
#         [ 0.2964, -0.3424, -0.3025,  0.2047, -0.0823,  0.0760,  0.3217, -0.0848,
#          -0.1697, -0.1430,  0.0583,  0.1524, -0.2867, -0.2453, -0.4549, -0.0583],
#         [ 0.2234, -0.4016, -0.3245,  0.2297, -0.1476,  0.0809,  0.2302,  0.0626,
#          -0.2089, -0.2434,  0.0294,  0.0790, -0.1018, -0.1844, -0.3611, -0.0423],
#         [ 0.4964, -0.0937, -0.4325,  0.3208, -0.4257, -0.0994,  0.4769,  0.1951,
#          -0.3780, -0.5220,  0.5034, -0.1119, -0.1035,  0.0320, -0.1968, -0.1656],
#         [ 0.4988, -0.0416, -0.2002,  0.3176, -0.2999,  0.0909,  0.4156, -0.0809,
#          -0.2754, -0.3607,  0.3477, -0.1822, -0.2184,  0.0618, -0.1873, -0.2428],
#         [ 0.3482, -0.1580, -0.2030,  0.2564, -0.1861,  0.1301,  0.3279, -0.1338,
#          -0.1915, -0.2261,  0.0505, -0.0494, -0.1343, -0.0880, -0.1502, -0.0986]],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# ### Questions:
#
# - Copy your code into `gpt_single_head.py`:
#   - Define the **key**, **query**, and **value** layers in the **constructor** of the `Head` class.
#   - Implement the **computations** in the `forward` function.
# - Train the model.
# - What are the **training** and **validation** losses?
# - Does the generated text appear **better** compared to the previous model?

# %% [markdown]
# **Comment**:
# At the last iteration, training and validation losses reache 2.3324 and 2.4422 respectively. The text is an improvement over the previous model—it no longer resembles a random string of special characters. The letters now form patterns that suggest words and are arranged across lines in a way that evokes verses. However, the sequence is still far from readable.
#
# <small>*Illà meutre ies cheurret! eurnde  l de ponex, ffrdana ratras!» pillauilelayhre,*
#
# <small>*Ett-s.*
#
# <small>*Sur e partt s à juitésomite lit a t s éreut fonsonse ves, tomandorre.*
#
# <small>*Qures?*
#
# <small>*) don deux, de, e l'ounèrer ler à gue prloitre lilluines lil-bola eux? vitet, prbobêmonau, 185*
#
# <small>*Le e Et   sai lelauont delonnes, bî;*
#
# <small>*Le ques proin foilsaiex  jerlalen! poisours sèn ditu,*
#
# <small>*L'és séconn'esileuxs mblesast,  à aueurje quere, reluérton lanantroistome, mabils elandser nétontorncier; vri éKsquu ecRux l'hueux, piteu j'aruessomur*

# %% [markdown]
# ## Multi-Head Attention
#
# Multi-head attention is simply the parallel computation of multiple **single-head attention** mechanisms. Each **single-head attention** output is concatenated to form the output of the **multi-head attention** module. In the original paper's illustration, the number of heads in the **multi-head attention** is denoted as `h`.
#
# To allow for **weighted combinations** of each single-head attention output, a **linear transformation layer** is added after concatenation.
#
# ![multi head attention](images/multi_head_attention.png)
#
# #### Questions:
#
# - In the **constructor**, create a list containing `num_heads` instances of the `Head` module using PyTorch’s [`ModuleList`](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html).
# - In the `forward` function:
#   - Apply each **single-head attention** to the input.
#   - Concatenate the results using PyTorch’s [`cat`](https://pytorch.org/docs/stable/generated/torch.cat.html) function.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        assert n_embd % num_heads == 0, "Embedding dimension must be divisible by number of heads"
        head_dim = n_embd // num_heads
        self.heads = nn.ModuleList([Head(head_dim, n_embd) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.proj(out)

        return out

# %% [markdown]
# #### Questions:
#
# 1. **Copy** the file `gpt_single_head.py` and rename it as `gpt_multi_head.py`.
# 2. **Add** the `MultiHeadAttention` module in `gpt_multi_head.py`.
# 3. At the **beginning of the file**, add a parameter:
#    ```python
#    n_head = 4
#    ```
# 4. In the `BigramLanguageModel` module, **replace** the `Head` module with `MultiHeadAttention`, using the parameters:
#    ```python
#    num_heads = n_head
#    head_size = n_embd // n_head
#    ```
#    This ensures the total number of parameters remains **the same**.
# 5. **Retrain the model** and note:
#    - The total number of **parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802
# ```

# %% [markdown]
# ```0.007616 M parameters```
#
# ```step 4999: train loss 2.1561, val loss 2.1703```
#
# <small>*à j'etre il qu'ecre;*
#
# <small>*Et funde soute eviex arbre Sa raicas!» pierrécordans;*
#
# <small>*Partres.*
#
# <small>*Sur espartt da foux;*
#
# <small>*L'oles lit det s'ére*
#
# <small>       *est vroistoiant laiematre somme, en à le que à fouxèrer lers suieltloitre la lyine*
#
# <small>*bril-tombreux? C'arte prombêmenaît désonile dan vore les aont de on mole trête ques proire seantant que lalen! poisilas sèrit tu,*
#
# <small>*L'éésavers, etileuxs l'a soir, là aueux,*
#
# <small>*Lèsere, ralué;*
#
# <small>*El la asprois,*
#
#
#
# <small>*A fablluiela da mon tonts noière vrières au saR del;*
#
# <small>*Et quirit le marcephombr*

# %% [markdown]
# ## Adding a FeedForward Computation Layer
#
# After the **attention layers**, which collect information from the sequence, a **computation layer** is added to combine all the gathered information.
#
# This layer is a simple **Multi-Layer Perceptron (MLP)** with:
# - One **hidden layer**,
# - A **ReLU non-linearity** using [`ReLU`](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
#
# ### Architecture:
#
# <img src="images/multi_ff.png" alt="multi feedforward" width="200">

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU and dropout """
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_head * n_embd),
            nn.ReLU(),
            nn.Linear(n_head * n_embd, n_embd)
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# #### Questions:
#
# 1. **Add** the `FeedForward` module to your `gpt_multi_head.py` file.
# 2. **Integrate** this `FeedForward` layer **after** the **multi-head attention** module.
# 3. **Retrain the model** and note:
#    - The total **number of parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216
# ```

# %% [markdown]
# ```0.019301 M parameters```
#
# ```step 4999: train loss 2.1278, val loss 2.1198  ```

# %% [markdown]
# ## Stacking Blocks
#
# The network we have built so far represents just **one block** of the final model. Now, we can **stack multiple blocks** of **multi-head attention** to create a **deeper** network.
#
# ### Architecture:
# ![multi feedforward](images/multi_bloc.png)
#
# The following code defines a **block**:

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# #### Questions:
#
# - Add the `Block` module to `gpt_multi_head.py`.
# - Modify the `BigramLanguageModel` code to include **three** instances of `Block(n_embd, n_head=4)`, using a [`Sequential`](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) container **instead of** `MultiHeadAttention` and `FeedForward`.
# - Retrain the model and note:
#   - The **number of parameters**
#   - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213
# ```

# %% [markdown]
# ```step 4999: train loss 1.9101, val loss 1.9414```
#
# <small>*Il vombrt la cheureur,*
#
# <small>*Hobeurs qu'hèbe et de nous quand lavedeupil au leur, les sorns cema espartillatenuit:--S'estrit: P'est-reils en arfiève!*
#
# <small>*La marde?*
#
# <small>*Quantre en ce vide, le na couris èter les m'une paloit de viluit.*
#
# <small>*Le l'aille extles et le boudions, trésonnoire*
#
# <small>*Pars palme;*
#
# <small>*La chelonnes,--T;*
#
# <small>*Le j'asa roire ellière, éje la glésant,*
#
# <small>*La poin dit.*
#
#
# <small>*L'éserécrine,*
#
# <small>*L'hungre pas sous luiseur,*
#
# <small>*Les pensis,*
#
# <small>*Il ma la approfolote, oabllève,*
#
# <small>*Pui mon tonts nous cétrières,*
#
# <small>*L'endre l'hueur luit,*
#
# <small>       *Lui q*

# %% [markdown]
# ## Improving Training
#
# If we want to continue increasing the **network size**, we need to incorporate layers that **enhance training stability** and **improve generalization** (reducing overfitting). These layers include:
#
# - **Skip connections** (or **residual connections**)
# - **Normalization layers**
# - **Dropout**
#
# ### Updated Architecture:
#
# <img src="images/multi_skip_norm.png" alt="multi feedforward" width="200">
#
# ---
#
# #### Questions:
#
# 1. In the `Block` module, **add a skip connection** by summing the input at each step:
#    ```python
#    x = x + self.sa(self.ln1(x))
#    x = x + self.ffwd(self.ln2(x))
#    ```
#
# 2. In the `Block` module, **add two** [`LayerNorm`](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) layers of size `n_embd`:
#    - **Before** the `Multi-Head Attention` layer.
#    - **Before** the `FeedForward` layer.
#
# 3. **After the sequence of 3 blocks**, add a **LayerNorm** layer of size `n_embd`.
#
# 4. Define a variable at the **beginning of the file**:
#    ```python
#    dropout = 0.2
#    ```
#    Then add a [`Dropout`](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) layer:
#    - **After** the `ReLU` activation in `FeedForward`.
#    - **After** the `Multi-Head Attention` layer in `MultiHeadAttention`.
#    - **After** the `softmax` layer in the single-head attention `Head`.
#
# 5. **Retrain the model** and note:
#    - The **number of parameters**
#    - The **training** and **validation** losses
#
# ---
#
# **Expected Output Example:**
# ```
# 0.019653 M parameters
# ```

# %% [markdown]
# ```0.044709 M parameters```
#
# ```step 4999: train loss 1.9775, val loss 2.0052```
#
# <small>*Qu'on mése paverlors.*
#
# <small>*J'our, de ce lotnile!*
#
# <small>*J'aridévent, a sa.*
#
# <small>*UNOs, que dant je le m'âtre pleur, venrit:*
#
# <small>*Ilèbre êtand nuier en paun félaiai-Mer mur groyoute rerfein et 18ns sui sord la pagant dit:--*
#
# <small>*XIr.*
#
# <small>*Il d'à vomme ain, avez,*
#
# <small>*Vois l'au brécrance!*
#
# <small>*Sui, aur,*
#
# <small>*Je le mont.*
#
# <small>*J'en nonss grincheur les sévendonns in pre.*
#
# <small>*Et l'oir lis mon mant, la sot de toux partâme; et de lontse! joubres.*
#
# <small>*Quei t'en rigiz-éair marle etrentemmmesec aux et cleur,*
#
# <small>*Je jis vouiron broune.*
#
# <small>*A pêmes plest vont nêt d*

# %% [markdown]
# ## Conclusion
#
# The key components of **GPT-2** are now in place. The next step is to **scale up** the model and train it on a **much larger** dataset. For comparison, the parameters of [GPT-2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) are:
#
# - **`vocab_size = 50257`** → GPT-2 models **subword tokens**, while we model **characters**. For us, `vocab_size = 100`.
# - **`n_positions = 1024`** → The maximum **context size**. For us, it's `block_size = 8`.
# - **`n_embd = 768`** → The **embedding dimension**. For us, it's `n_embd = 32`.
# - **`n_layer = 12`** → The number of **blocks**. For us, it's `3`.
# - **`n_head = 12`** → The number of **multi-head attention layers**. For us, it's `4`.
#
# Overall, **GPT-2** consists of **1.5 billion parameters** and was trained on **8 million web pages**, totaling **40 GB of text**.
#
# ---
#
# ### **Training Results**
# ```text
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
# ```
#
# ### **Generated Text Sample:**
#
# ```text
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
